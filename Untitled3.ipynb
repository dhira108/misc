# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import numpy as np
import pandas as pd
import matplotlib
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
matplotlib.style.use('ggplot')
# %matplotlib inline
from sklearn.decomposition import PCA
import seaborn as sns

# %%
data=pd.read_csv("beispiel.csv", sep=";")

# %%
data=data.iloc[:,1:data.shape[1]]

# %%
data.head(15)
# Out:
#            make fuel.type aspiration num.of.doors   body.style drive.wheels  \
# 1   alfa-romero       gas        std          two  convertible          rwd
# 2   alfa-romero       gas        std          two  convertible          rwd
# 3   alfa-romero       gas        std          two    hatchback          rwd
# 4          audi       gas        std         four        sedan          fwd
# 5          audi       gas        std         four        sedan          4wd
# 6          audi       gas        std          two        sedan          fwd
# 7          audi       gas        std         four        sedan          fwd
# 8          audi       gas        std         four        wagon          fwd
# 9          audi       gas      turbo         four        sedan          fwd
# 10         audi       gas      turbo          two    hatchback          4wd
# 11          bmw       gas        std          two        sedan          rwd
# ...

# %%
data_n=data._get_numeric_data()

# %%
data["horsepower"]=data["horsepower"].astype("float64")

# %%
featurescat=list(set(data.columns)- set(data._get_numeric_data().columns))

# %%
for i, feat in enumerate (featurescat) :
    data[feat]=pd.factorize(data[feat])[0]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 205 entries, 1 to 205
# Data columns (total 26 columns):
# normalized.losses    205 non-null object
# make                 205 non-null int64
# fuel.type            205 non-null int64
# aspiration           205 non-null int64
# num.of.doors         205 non-null int64
# body.style           205 non-null int64
# drive.wheels         205 non-null int64
# engine.location      205 non-null int64
# wheel.base           205 non-null float64
# length               205 non-null float64
# width                205 non-null float64
# height               205 non-null float64
# curb.weight          205 non-null int64
# engine.type          205 non-null int64
# num.of.cylinders     205 non-null int64
# engine.size          205 non-null int64
# fuel.system          205 non-null int64
# bore                 205 non-null int64
# stroke               205 non-null int64
# compression.ratio    205 non-null float64
# ...

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()
ddd=data.drop("symboling", axis=1)
dd_sc=scale.fit_transform(ddd)


from sklearn import decomposition
from sklearn.decomposition import PCA
pca = decomposition.PCA(n_components=3)

pca = decomposition.PCA(n_components=3)
dd_reduced = pca.fit_transform(dd_sc)


plt.figure(figsize=(12,10))
plt.scatter(dd_reduced[:, 0], dd_reduced[:, 1], c=data["fuel.system"].map({0: "blue", 1: "orange",2: "green", 3:"black",4:"brown", 5:"pink",6:"yellow",7:"red"}), 
            edgecolor='none', alpha=0.7, s=100);

# %%
from sklearn.preprocessing import StandardScaler
scale=StandardScaler()

dd_sc=scale.fit_transform(data)


from sklearn.manifold import TSNE
tsne = TSNE(random_state=17, metric="cosine")


X_tsne = tsne.fit_transform(ddd)

plt.figure(figsize=(12,10))
plt.scatter(X_tsne[:, 0], X_tsne[:, 1],c=data["fuel.system"].map({0: "blue", 1: "orange",2: "green", 3:"black",4:"brown", 5:"pink",6:"yellow",7:"red"}), s=100)##
TSNE
# Out:
# sklearn.manifold.t_sne.TSNE

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly
plotly.tools.set_credentials_file(username='dhira88', api_key='j57TcvFszvEhmqMuVLwi')
import numpy as np


trace1 = go.Scatter3d(
    x=dd_reduced[:, 0],
    y=dd_reduced[:, 1],
    z=dd_reduced[:, 2],
    mode='markers',
    marker=dict(
        size=7,
        color=fs,
        line=dict(
            
            width=0.2
        ),
        opacity=0.7
    )
)

data = [trace1]
layout = go.Layout(
    margin=dict(
        l=0,
        r=0,
        b=0,
        t=0
    )
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='3d-scatter-colorscale')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~dhira88/4.embed" height="525px" width="100%"></iframe>

# %%
data["fuel.system"].value_counts()
# Out:
# mpfi    94
# 2bbl    66
# idi     20
# 1bbl    11
# spdi     9
# 4bbl     3
# spfi     1
# mfi      1
# Name: fuel.system, dtype: int64

# %%
bs=data["body.style"].map({0: 'blue', 1: 'orange',2: "green", 3:"black",4:"brown"})

# %%
ft=data["fuel.type"].map({0: 'blue', 1: 'orange'})

# %%
fs=data["fuel.system"].map({0: "blue", 1: "orange",2: "green", 3:"black",4:"brown", 5:"pink",6:"yellow",7:"red"})

# %%
asp=data["aspiration"].map({0: 'blue', 1: 'orange'})

# %%
data["fuel.system"].value_counts()
# Out:
# 0    94
# 1    66
# 6    20
# 3    11
# 7     9
# 5     3
# 4     1
# 2     1
# Name: fuel.system, dtype: int64
